# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')

# %%
x_train=np.array([1.0,2.0])
y_train=np.array([300.0,500.0])
print(f'x_train = {x_train}')
print(f'y_train = {y_train}')
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
print(f'x_train.shape = {x_train.shape}')
m=x_train.shape[0]
print(f'Number of training examples: {m}')
# Out:
# x_train.shape = (2,)
# Number of training examples: 2

# %%
m=len(x_train)
print(f'Number of training examples: {m}')
# Out:
# Number of training examples: 2

# %%
i=0
x_i=x_train[i]
y_i=y_train[i]
print(f'(x^({i}),y^({i}))=({x_i},{y_i})')
# Out:
# (x^(0),y^(0))=(1.0,300.0)

# %%
plt.scatter(x_train,y_train,c='r',marker='x')
plt.title("Housing Prices")
plt.ylabel("Price in 1000s of Dollars")
plt.xlabel("Size in 1000s feet")
plt.show()

# %%
w=200
b=100
print(f'w = {w}')
print(f'b = {b}')
# Out:
# w = 200
# b = 100

# %%
def compute_model_output(x,w,b):
    m=x.shape[0]
    f_wb=np.zeros(m)
    for i in range m:
        f_wb[i]=
# Out:
# 2

# %%
tmp_f_wb=compute_model_output(x_train,w,b)

plt.scatter(x_train,y_train,c='r',marker='x',label='Actual Values')
plt.plot(x_train,tmp_f_wb, c='b', label='Our Prediction')
plt.ylabel('Price in 1000s of $')
plt.xlabel('Size in 100 square feet')
plt.legend()
plt.show()

# %%
x_i=1.2
cost_1200sqft=w*x_i+b
print(f'Cost of 1200 feet = {cost_1200sqft} $')
# Out:
# Cost of 1200 feet = 340.0
